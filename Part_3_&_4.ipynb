# %% [markdown]
# <a href="https://colab.research.google.com/github/amnamalik1993/Sales-Prediction/blob/main/Part_3_%26_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Part 3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Importing**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# # **Loading Data**

# %%
filename = '/content/sales_predictions.csv'
df = pd.read_csv('/content/sales_predictions.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ## Exploratory Visuals & Analysis

# %% [markdown]
# There are a number of ways of plotting the data. We will go Column-by-Column with the EDA using a function (plus markdown interpretations for each)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# *   For each numeric feature, we will plot the distribution and a boxplot.

# %%
num_cols = df.select_dtypes('number').columns
num_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# **1. EDA Using Loops**

# %% [markdown]
# Column-by-Column EDA using a function (plus markdown interpretations for each)

# %%
df['Item_Outlet_Sales'].value_counts()
# Out:
# 958.7520     17
# 1342.2528    16
# 703.0848     15
# 1845.5976    15
# 1278.3360    14
#              ..
# 4124.6310     1
# 6622.7126     1
# 1614.5650     1
# 5602.7070     1
# 2778.3834     1
# Name: Item_Outlet_Sales, Length: 3493, dtype: int64

# %%
def plot_numeric(df,col):
  """EDA function to plot a histogram and boxplot for the selected column"""
  ## make the figure and axes sharing the same x-axis
  fig, axes = plt.subplots(nrows=2, figsize=(10,5), sharex=True)

  ## Use seaborn plots with ax=axes[i]
  sns.histplot(data=df,x = col,ax = axes[0])
  mean_value = df[col].mean()
  axes[0].axvline(mean_value,color='red', ls='--', 
           label=f"Mean Value = ${mean_value:,.2f}",);

  med_value = df[col].median()
  axes[0].axvline(med_value,color='black', ls='--', 
           label=f"Median Value = ${med_value:,.2f}");


  sns.boxplot(data=df, x = col, ax = axes[1])

  ## Updating title of top graph 
  axes[0].set_title(f'EDA for {col}')

  ## Fixing any overlapping labels and showing
  plt.tight_layout()
  plt.show()

# %%
plot_numeric(df,'Item_Outlet_Sales')

# %% [markdown]
# *   Here on the boxplot, you can clearly see that there are several outliers in the Item Outlet Sales column. These could be valid data points, or they could be an error.
#
#
# *   Some product sales are significantly higher than other. This all is included in the dataset.

# %%
plot_numeric(df,'Item_Weight')

# %% [markdown]
# *   Both plots show that there is not much difference in Item Weight between all items. The median weight of items are between the range almost 8 to 17.

# %% [markdown]
# **Visualizing** **with** **Barplots**

# %% [markdown]
# *   We will view the categorical counts of all of the object type columns and visualize this information with a barplot.

# %%
## functionize a barplot and call it plot_bar

def plot_bar(data,x, y, figsize=(20,5)):
    ## Make a larger fig/ax before plotting
    fig, ax = plt.subplots(figsize=figsize)

    ## Plot barplot
    
    ## counts, counts up the categories, sort the values, then puts them in a 
    ## data frame.
    
    counts = df[x].value_counts().sort_values(ascending=False).to_frame()
    ## ploting the barplot

    sns.barplot(data=counts,x=counts.index, y = counts[x],ax=ax)

    plt.xticks(rotation= 90)
    ax.set_title(f'Categorical Frequencies of {y}', fontsize = 20, fontweight = 'bold');
    ax.set_xlabel(f'Categories for {y}', fontsize = 15, fontweight = 'bold')
    ax.set_ylabel('Counts', fontsize = 15, fontweight = 'bold')

    return fig,ax

# %%
Item_Fat_Content_Map = {'LF':'Low Fat',
                   'low fat':'Low Fat',
                   'reg':'Regular'}

df['Item_Fat_Content'] = df['Item_Fat_Content'].replace(Item_Fat_Content_Map)

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
fig, ax = plot_bar(df, 'Item_Fat_Content', 'Item Fat Content');
print(df['Item_Fat_Content'].value_counts())
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# * From this graph, we can see that there are mostly Low Fat items in this dataset.
# *  Count for Item with Low Fat is more Regular Fat. There are more items which have low fat as compared to regular fat.

# %%
fig, ax = plot_bar(df, 'Item_Type', 'Item Type')
print(df['Item_Type'].value_counts())
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %% [markdown]
# *   From the graph, we can see there are many types of item in this dataset
# *   The most popular item type is Fruits and Vegatables with the highest count. The least popular is Seafood with the lowest count.

# %%
fig, ax = plot_bar(df, 'Outlet_Size', 'Outlet Size')
print(df['Outlet_Size'].value_counts())
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %% [markdown]
# *   From the graph, we can see there are three outlet sizes.
# *   Medium outlet size is more than small and high.

# %%
fig, ax = plot_bar(df, 'Outlet_Location_Type', 'Outlet Location Type')
print(df['Outlet_Location_Type'].value_counts())
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %% [markdown]
# *   There are three outlet location type.
# *   Tier 3 is higher than Tier 1 and Tier 2

# %%
Outlet_Type_Map = {'Supermarket Type1':'Supermarket Type',
                   'Supermarket Type2':'Supermarket Type',
                   'Supermarket Type3':'Supermarket Type'}

df['Outlet_Type'] = df['Outlet_Type'].replace(Outlet_Type_Map)

# %%
fig, ax = plot_bar(df, 'Outlet_Type', 'Outlet Type')
print(df['Outlet_Type'].value_counts())
# Out:
# Supermarket Type    7440
# Grocery Store       1083
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# *   There are 2 types of Outlet
# *   Supermarkets are more famous than the Grocery Store. They have more Supermarket as compared to Grocery Store

# %%
fig, ax = plot_bar(df, 'Outlet_Establishment_Year', 'Outlet Establishment Year')
print(df['Outlet_Establishment_Year'].value_counts())
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %% [markdown]
# *   The sales are greatest in 1985 and lowered in 2009
# *   From 1999 to 2009, the sales have been constant.

# %%
sns.heatmap(df.corr(),annot=True,cmap='Reds');

# %% [markdown]
# *   There aren't really any strong or even moderate correlations shown here.

# %% [markdown]
# **Big-Picture EDA/ All Features At Once**

# %%
sns.pairplot(df);

# %% [markdown]
# *  Item outlet sales are dropping.
# *  Sales were greatest before 1990 as compared to 2010

# %% [markdown]
# Part 4

# %% [markdown]
# For Part 4, our task is to build several data visualizations to help stakeholders better understand trends in the data. Feel free to get creative with this week - this is your chance to set your project apart from others with exceptional visualizations and analyses.
#
#
#
# *   We will build on our previous cleaning, exploration, and analysis.
# *   Create a minimum of two data visualizations that help others understand trends in the data (explanatory data analysis).
#
# *   Since these graphs are for reporting purposes, make sure they look nice by including titles, legends, etc.

# %% [markdown]
# Possible Questions to Answer:
#
# 1: Which item type generates the most and least sales?
#
# 2: Which item fat content generates the most and least sales?
#
# 3: What is the trend for sales for the last 10 years?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# 1: Which item type generates the most and least sales?

# %%
means = df.groupby('Item_Type')['Item_Outlet_Sales'].mean().sort_values(ascending=False)
means
# Out:
# Item_Type
# Starchy Foods            2374.332773
# Seafood                  2326.065928
# Fruits and Vegetables    2289.009592
# Snack Foods              2277.321739
# Household                2258.784300
# Dairy                    2232.542597
# Canned                   2225.194904
# Breads                   2204.132226
# Meat                     2158.977911
# Hard Drinks              2139.221622
# Frozen Foods             2132.867744
# Breakfast                2111.808651
# Health and Hygiene       2010.000265
# Soft Drinks              2006.511735
# Baking Goods             1952.971207
# Others                   1926.139702
# Name: Item_Outlet_Sales, dtype: float64

# %%
from matplotlib.ticker import FuncFormatter
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.barplot(data=df,x='Item_Type', y = 'Item_Outlet_Sales', order = means.index, ci = None)
plt.xticks(rotation = 90)
ax.set_title('Average Outlet Sales vs. Item Type', fontsize = 20, fontweight = 'bold');
ax.set_xlabel('Item Type', fontsize = 15, fontweight = 'bold')
ax.set_ylabel('Item Outlet Sales', fontsize = 15, fontweight = 'bold');

# %% [markdown]
# The top three highest sales product and average sales are as follows:
#
# *   Starchy Foods is generating the most sales. It is generating more than 2000
# *   Seafood is the second with sales more than 2000 but less than Starchy Food sales.
#
# *   Third is Fruits and vegetables.
#
#
# The bottom item types generating the least sales are
#
#
# *   Bakery goods
# *   Others

# %% [markdown]
# 2: Which item fat content generates the most and least sales?

# %%
means2 = df.groupby('Item_Fat_Content')['Item_Outlet_Sales'].mean().sort_values(ascending=False)
means2
# Out:
# Item_Fat_Content
# Regular    2224.561170
# Low Fat    2157.711534
# Name: Item_Outlet_Sales, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.barplot(data=df,x='Item_Fat_Content', y = 'Item_Outlet_Sales', order = means2.index, ci = None)
plt.xticks(rotation = 90)
ax.set_title('Average Sales vs. Item Fat Content', fontsize = 20, fontweight = 'bold');
ax.set_xlabel('Item Fat Content', fontsize = 15, fontweight = 'bold')
ax.set_ylabel('Item Outlet Sales', fontsize = 15, fontweight = 'bold');

# %% [markdown]
# The top and bottom item with fat content and average sales is as follows:
#
#
# *   Item with Regular Fat Content is generating more sales.
# *   Item with Low Fat Content is generating less sales.
# *   There is not a much difference in the average sales between both

# %% [markdown]
# 3: What is the trend for sales for the last 10 years?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    1463
# 1987     932
# 1999     930
# 1997     930
# 2004     930
# 2002     929
# 2009     928
# 2007     926
# 1998     555
# Name: Outlet_Establishment_Year, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,10))

ax = sns.lineplot(data=df,x = 'Outlet_Establishment_Year', y = 'Item_Outlet_Sales')
ax.set_title('', fontsize = 20, fontweight = 'bold');

labels = [0,1985,2004,2009]

ax.set_xticklabels(labels)
plt.locator_params(axis='x', nbins=3)

ax.set_xlabel('Establishment Year', fontsize = 15, fontweight = 'bold')
ax.set_ylabel(f'Outlet Sales', fontsize = 15, fontweight = 'bold');
# Out:
# <ipython-input-56-eb07246d075a>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels)

# %% [markdown]
# This graph shows most sales occurred before 1985. After that there was a decline in the early 2000s. It is picking back up after 2004. Still not where it was before 1985.
